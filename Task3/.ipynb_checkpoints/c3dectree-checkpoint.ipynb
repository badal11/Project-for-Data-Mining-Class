# %%
import pandas as pd
import import_ipynb
from encode import *
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
clf = tree.DecisionTreeClassifier()

# %%
df = pd.read_excel("transformed2.xlsx")
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df = df.fillna(df.mean())
df1 = df.fillna(method='ffill')
#df1 = df1.drop(['Engine Size', 'Engine Block', 'Auto In The Market: New', 'Auto In The Market: Used', 'Model 1', 'Engine Cylinders', 'Drive Type', 'Fuel Type', 'Make 1', 'Unnamed: 0'], axis=1)

# %%
#df1 = encode(df1)

# %%
ysplit = df1['Person Type']
xsplit = df1.drop(['Person Type'],axis=1)
dt = xsplit.select_dtypes(include=['datetime64'])
cat2 = list(dt.columns)
categorical = xsplit.select_dtypes(exclude=['float64'])
cat3 = list(categorical.columns)
cols = cat2 + cat3
le = preprocessing.LabelEncoder()
xsplit[cols] = xsplit[cols].apply(lambda col: le.fit_transform(col))
#xsplit = pd.get_dummies(xsplit, columns=cols)
#xsplit

# %%
#xsplit

# %%
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(xsplit,ysplit)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(xsplit.columns)
fes = pd.concat([dfcolumns,dfscores],axis=1)
fes.columns = ['Specs','Score']
fes.nlargest(15,'Score')
fes = fes.sort_values(by =['Score'],ascending=False)
large = fes.head(10)

corr = large['Specs'].values
xsplit1 = xsplit[corr]

# %%
fes
# Out:
#                                                  Specs         Score
# 197                 Census 2010: Tract and block group  6.294333e+06
# 12                        Estimated Current Home Value  2.743625e+05
# 97               CAPE: HomVal: OOHU: Median Home Value  1.662021e+05
# 116      CAPE: Inc: HH: Median Family Household Income  1.884792e+04
# 2                                                Acct#  1.177465e+04
# 172                                Person Combined Age  6.617939e+03
# 72                                                USNG  4.980721e+03
# 45             Estimated Monthly Mortgage Pay - Amount  3.814725e+03
# 66                               Person Marital Status  3.092831e+03
# 193                              Household Composition  2.275122e+03
# 13                            Home Land Square Footage  1.888964e+03
# 96                     CAPE: Ethnic: Pop: % Black Only  1.646076e+03
# 89   Person Combined Age - Skip first byte when append  1.489577e+03
# 51                        Home Mortgage Term in months  1.368828e+03
# 7                                       Home Tax Value  1.335750e+03
# 24    Ethnic Insight - Alphanumeric Ethnic Detail Code  8.692719e+02
# 106            CAPE: Tenancy: OCCHU: % Renter Occupied  8.292641e+02
# 3                              Home Land Front Footage  8.268694e+02
# 135                                Length of Residence  7.330966e+02
# 145             Estimated Equity - Amount in thousands  6.975973e+02
# 52                                       Person Number  6.888959e+02
# 5                                       Vehicle 1 Trim  6.616602e+02
# 42                        Owner Occupied - Equity Term  6.613057e+02
# 1                              Home Land Depth Footage  6.553118e+02
# 125              Estimated Current Loan-to-Value Ratio  6.414823e+02
# 77   Person Occupation Group V2 - Available Decembe...  6.304969e+02
# 104                                   Mosaic Household  5.316401e+02
# 196                                        County Name  5.306578e+02
# 195                        Homeowner Probability Model  5.077062e+02
# 179                    Owner Occupied - Refinance Term  4.782572e+02
# ..                                                 ...           ...
# 128                                             Year 1  5.564764e+00
# 43                  CAPE: Inc: Family Inc State Decile  5.465312e+00
# 47                      MOR Bank - Upscale Merch Buyer  4.776282e+00
# 173                   MOR Bank Gifts and Gadgets Buyer  4.733947e+00
# 138                           CAPE: Educ: ISPSA Decile  4.455222e+00
# 105                 MOR Bank - Crafts/Hobb Merch Buyer  4.144154e+00
# 50                       Children: Age 16-18 Version 3  3.315700e+00
# 78       CAPE: Educ: Pop25+: Median Education Attained  3.282945e+00
# 92                            Number of Children in LU  3.031749e+00
# 155                       Home Swimming Pool Indicator  2.280350e+00
# 132                              Home Air Conditioning  2.274016e+00
# 112                                   Phone DNC Status  2.133766e+00
# 123                                       Engine Block  2.097747e+00
# 14                                         Engine Size  2.085550e+00
# 16                                    Engine Cylinders  2.079952e+00
# 21                      MOR Bank Religious Contributor  2.012635e+00
# 151                                    Home Fireplaces  1.725193e+00
# 152                            Home Property Indicator  1.696298e+00
# 31                                          Drive Type  1.041801e+00
# 184                                          Time Zone  8.200633e-01
# 166                                     Recipient Code  7.244685e-01
# 18                                    Move Update Code  6.439410e-01
# 168        Estimated Mortgage Amount - Confidence Flag  6.211829e-01
# 94    Estimated Monthly Mortgage Pay - Confidence Flag  6.211829e-01
# 103                 Estimated Equity - Confidence Flag  6.211829e-01
# 185                               MOR Bank Photography  3.156566e-01
# 139               MOR Bank Collect/Special Foods Buyer  3.088636e-01
# 34                                            MOR Bank  3.046264e-01
# 32                                           Fuel Type  9.591542e-02
# 158                                                DPV  5.485825e-02
#
# [198 rows x 2 columns]

# %%
xtrain, xtest = train_test_split(xsplit1, test_size=0.2, shuffle=False)
ytrain, ytest = train_test_split(ysplit, test_size=0.2, shuffle=False)

# %%
#param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
#clf = GridSearchCV(clf, param_grid, cv=5, n_jobs=4) 

clf = clf.fit(xtrain,ytrain)

# %%
ypred = clf.predict(xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.976

# %%
from yellowbrick.classifier import ClassPredictionError, ClassificationReport, ROCAUC, PrecisionRecallCurve, ConfusionMatrix
model = tree.DecisionTreeClassifier()
viz = ClassPredictionError(model)
viz.fit(xtrain,ytrain)
viz.score(xtest,ytest)
viz.show()

classes = ["P", "E", "Y", "O"]
viz = ClassificationReport(model, classes=classes, support=True)
viz.fit(xtrain,ytrain)
viz.score(xtest,ytest)
viz.show()
 
classes = ["P", "E", "Y", "O"]
viz = ROCAUC(model, classes=classes)
viz.fit(xtrain,ytrain)
viz.score(xtest,ytest)
viz.show()
 
viz = PrecisionRecallCurve(model)
viz.fit(xtrain,ytrain)
viz.score(xtest,ytest)
viz.show()
 
classes = ["P", "E", "Y", "O"]
viz = ConfusionMatrix(model,classes=classes,label_encoder={0: 'P', 1: 'E', 2: 'Y', 3: 'O'})
viz.fit(xtrain,ytrain)
viz.score(xtest,ytest)
viz.show()
