# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("transformed1.xlsx")

# %%
df3 = pd.read_excel("transformed1.xlsx")
cols = sorted(df3.columns)
for x in cols:
    print(x)
# Out:
# Acct#
# Additional investment flag
# Address ID
# Auto In The Market: New
# Auto In The Market: Used
# BehaviorBank: Cat Enthusiast
# BehaviorBank: Computer Owner
# BehaviorBank: Contributes to Charities
# BehaviorBank: Cruise Enthusiasts
# BehaviorBank: Dog Enthusiasts
# BehaviorBank: Donates to Environmental Causes
# BehaviorBank: Home Decorating/Furnishing
# BehaviorBank: Interest in Automotive
# BehaviorBank: Interest in Domestic Travel
# BehaviorBank: Interest in Fitness
# BehaviorBank: Interest in Foreign Travel
# BehaviorBank: Interest in Gardening
# BehaviorBank: Interest in Gourmet Cooking
# BehaviorBank: Interest in Reading
# BehaviorBank: Interest in Sports
# BehaviorBank: Interest in Travel
# BehaviorBank: Interest in the Outdoors
# BehaviorBank: Internet/Online Subscriber
# BehaviorBank: Invest in Mutual Funds/Annuities
# BehaviorBank: Investor
# BehaviorBank: Pet Enthusiast
# BehaviorBank: Presence of Credit Card
# BehaviorBank: Presence of Premium Credit Card
# ...

# %%
df2 = df.filter(regex='MOR')

# %%
#df3 = df
#df = df.join(df2['Homeowner Probability Model'])

# %%
df2 = df2.drop(['Homeowner Probability Model'],axis=1)

# %%
df2.columns
# Out:
# Index(['Home Purchase Price', 'Home Land Depth Footage',
#        'Home Land Front Footage', 'Home Improvement Value', 'Home Tax Value',
#        'Home Base Square Footage', 'Home Land Value', 'Home Total Value',
#        'Home Land Square Footage', 'Home Building Construction Indicator',
#        'Home Mortgage Term in months', 'Home Heat Indicator',
#        'Home Total Rooms', 'Home Building Square Footage', 'Home Business',
#        'Home Bath', 'Home Air Conditioning', 'Home Floor Cover Indicator',
#        'Combined Homeowner/Renter', 'Home Bedrooms', 'Home Fireplaces',
#        'Home Property Indicator', 'Home Swimming Pool Indicator',
#        'Home Exterior Wall Type', 'Home Stories',
#        'Homeowner Probability Model'],
#       dtype='object')

# %%
df.drop(['Living Unit ID'],axis=1,inplace=True)

# %%
for x in df2.columns:
    df.drop([x],axis=1,inplace=True)

# %%
df2
