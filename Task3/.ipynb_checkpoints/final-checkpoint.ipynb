# %%
import pandas as pd
import import_ipynb
from encode import *
from sklearn import tree
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# Out:
# importing Jupyter notebook from encode.ipynb

# %%
clf = tree.DecisionTreeClassifier()

# %%
df = pd.read_excel("transformed5.xlsx")

# %%
df = df.fillna(df.mean())
df1 = df.fillna(method='ffill')
#df1 = df1.drop(['Engine Size', 'Engine Block', 'Auto In The Market: New', 'Auto In The Market: Used', 'Model 1', 'Engine Cylinders', 'Drive Type', 'Fuel Type', 'Make 1', 'Unnamed: 0'], axis=1)

# %%
#df1 = encode(df1)

# %%
ysplit = df1['Vehicle Type']
xsplit = df1.drop(['Vehicle Type'],axis=1)
dt = xsplit.select_dtypes(include=['datetime64'])
cat2 = list(dt.columns)
categorical = xsplit.select_dtypes(exclude=['float64'])
cat3 = list(categorical.columns)
cols = cat2 + cat3
le = preprocessing.LabelEncoder()
xsplit[cols] = xsplit[cols].apply(lambda col: le.fit_transform(col))
#xsplit = pd.get_dummies(xsplit, columns=cols)
#xsplit

# %%
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(xsplit,ysplit)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(xsplit.columns)
fes = pd.concat([dfcolumns,dfscores],axis=1)
fes.columns = ['Specs','Score']
fes.nlargest(15,'Score')
fes = fes.sort_values(by =['Score'],ascending=False)
large = fes.head(150)

corr = large['Specs'].values
xsplit1 = xsplit[corr]

# %%
fes
# Out:
#                                                    Specs        Score
# 21533                                 Engine Cylinders_8  2240.003566
# 0                                            Engine Size  2048.515368
# 21667                                     Drive Type_FWD  2037.622966
# 21663                                     Drive Type_4WD  1603.089371
# 21099                                      Model 1_F-150  1586.358209
# 21150                              Model 1_GRAND CARAVAN  1585.680412
# 21457                           Model 1_TOWN AND COUNTRY  1553.319588
# 21530                                 Engine Cylinders_4  1384.624421
# 21285                                    Model 1_ODYSSEY  1294.432990
# 21665                                     Drive Type_4X4  1160.821973
# 21399                             Model 1_SILVERADO 1500  1158.458955
# 22054                                     Engine Block_I  1084.440084
# 21704                                        Make 1_JEEP   974.774070
# 22056                                     Engine Block_V   880.837041
# 21332                            Model 1_RAM PICKUP 1500   855.798507
# 21391                                     Model 1_SIENNA   825.201031
# 21666                                     Drive Type_AWD   706.233525
# 21664                                     Drive Type_4X2   652.930844
# 21532                                 Engine Cylinders_6   611.065365
# 21689                                    Make 1_CHRYSLER   574.675009
# 20824                                  Vehicle 1 Trim_XL   518.439605
# 21670                                        Fuel Type_D   502.566214
# 21671                                        Fuel Type_F   469.480732
# 21697                                         Make 1_GMC   468.799131
# 21392                                Model 1_SIERRA 1500   464.427239
# 20722                                  Vehicle 1 Trim_ST   463.468639
# 21692                                       Make 1_DODGE   455.087672
# 20809                          Vehicle 1 Trim_WORK TRUCK   443.554104
# 21339                                     Model 1_RANGER   433.117537
# 20978                                    Model 1_CARAVAN   404.510309
# ...                                                  ...          ...
# 23549                                Address ID_36896173     0.404361
# 22502                     Homeowner Probability Model_35     0.399807
# 22501                     Homeowner Probability Model_34     0.399427
# 22385         Estimated Current Loan-to-Value Ratio_3100     0.387967
# 22159         Estimated Current Loan-to-Value Ratio_1101     0.382340
# 21754                    Home Building Square Footage_15     0.374574
# 21830                          Congressional District_11     0.365474
# 21898                     MOR Bank General Merch Buyer_0     0.337392
# 22152         Estimated Current Loan-to-Value Ratio_1094     0.334102
# 21592  Ethnic Insight - Alphanumeric Ethnic Detail Co...     0.300065
# 22354         Estimated Current Loan-to-Value Ratio_3069     0.300065
# 22039                                 Phone DNC Status_1     0.290439
# 21561  Ethnic Insight - Alphanumeric Ethnic Detail Co...     0.285683
# 21833                          Congressional District_14     0.284667
# 22305         Estimated Current Loan-to-Value Ratio_3020     0.276611
# 21912                          Auto In The Market: New_7     0.267103
# 21916                                Person Occupation_2     0.253557
# 21793                    Home Building Square Footage_54     0.235303
# 21750                    Home Building Square Footage_11     0.226399
# 21901                     MOR Bank General Merch Buyer_3     0.222588
# 21885                         Auto In The Market: Used_5     0.195200
# 22147         Estimated Current Loan-to-Value Ratio_1089     0.184356
# 21762                    Home Building Square Footage_23     0.170758
# 22442                                Person Education_54     0.156419
# 22381         Estimated Current Loan-to-Value Ratio_3096     0.153062
# 21536    BehaviorBank: Donates to Environmental Causes_U     0.112362
# 22042                       Additional investment flag_U     0.098621
# 22124         Estimated Current Loan-to-Value Ratio_1066     0.098008
# 22425                         Est. Household Income V5_D     0.060150
# 21998                                  Down payment %_41     0.036863
#
# [27734 rows x 2 columns]

# %%
xtrain, xtest = train_test_split(xsplit1, test_size=0.2, shuffle=False)
ytrain, ytest = train_test_split(ysplit, test_size=0.2, shuffle=False)

# %%
#param_grid = { 'criterion':['gini','entropy'],'max_depth': np.arange(3, 15)}
#clf = GridSearchCV(clf, param_grid, cv=5, n_jobs=4) 

clf = clf.fit(xtrain,ytrain)

# %%
ypred = clf.predict(xtest)

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9505
